# %% [markdown]
# <a href="https://colab.research.google.com/github/Pechuguin/Extracci-n-de-caracteristicas/blob/main/Extraccion_de_caracteristicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Identificar valores nulos por columna
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()

# %%
#Imprimimos los primeros 5 registros del Dataframe
Micro_Retailer.head()

# %%
#Obtengo un analisis univariado de las variables categoricas
freq_tbl(Micro_Retailer)

# %%
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table1= freq_tbl(Micro_Retailer["214_customer_relationship_tools"])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('214_customer_relationship_tools')
Filtro_index

# %%
#diagrama del Dataframe filtrado
Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")

# %%
#filtro para vaiables cuantitativas
Micro2=Micro_Retailer.iloc[:,[52,53,55,63,64,66,67,68,69,70,71,72,73,74,75,76,77,79,80,81]]#VAIRABLES cuantitativas, columnnas
Micro2

# %%
Micro2.info()

# %%
#Sustituir valores nulos con promedio o media
Micro2["314_reception_delivery_packages"] =Micro2["314_reception_delivery_packages"].fillna("NONE")
Micro2["42_willingness_share_inventory_data_suppliers"] =Micro2["42_willingness_share_inventory_data_suppliers"].fillna("NONE")
Micro2["46_willingness_reorder_suppliers_variety"] =Micro2["46_willingness_reorder_suppliers_variety"].fillna("NONE")
Micro2["47_willingness_reorder_suppliers_lower_prices"] =Micro2["47_willingness_reorder_suppliers_lower_prices"].fillna("NONE")
Micro2["38_average_margin_profits"] =Micro2["38_average_margin_profits"].fillna("NONE")
Micro2["312_payment_of_utilities"] =Micro2["312_payment_of_utilities"].fillna("NONE")
Micro2["313_home_deliveries"] =Micro2["313_home_deliveries"].fillna("NONE")
Micro2["60_services"] =Micro2["60_services"].fillna("NONE")
Micro2["311_topups"] =Micro2["311_topups"].fillna("NONE")
Micro2["193_sales_planning_tools"] =Micro2["193_sales_planning_tools"].fillna("NONE")
Micro2["53_special_conditions_suppliers"] =Micro2["53_special_conditions_suppliers"].fillna("NONE")
Micro2["278_credit_interest"] =Micro2["278_credit_interest"].fillna("NONE")
Micro2["59_willingness_share_sales_data_mse_better_prices"] =Micro2["59_willingness_share_sales_data_mse_better_prices"].fillna("NONE")
Micro2["185_place_orders_suppliers"] =Micro2["185_place_orders_suppliers"].fillna("NONE")
Micro2["44_willingness_inventory_management_suppliers"] =Micro2["44_willingness_inventory_management_suppliers"].fillna("NONE")
Micro2["45_willingness_reorder_suppliers"] =Micro2["45_willingness_reorder_suppliers"].fillna("NONE")
Micro2["66_percentaje_services_income"] =Micro2["66_percentaje_services_income"].fillna("NONE")
Micro2["64_comission_services"] =Micro2["64_comission_services"].fillna("NONE")
Micro2["43_willingness_share_sales_data_suppliers"] =Micro2["43_willingness_share_sales_data_suppliers"].fillna("NONE")
Micro2["58_willingness_share_sales_data_mse"] =Micro2["58_willingness_share_sales_data_mse"].fillna("NONE")

# %%
#Identificar valores nulos por columna
valores_nulosM2=Micro2.isnull().sum()
valores_nulosM2

# %%
table_1= freq_tbl(Micro_Retailer["185_place_orders_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1]
Filtro_index_1=Filtro_1.set_index("185_place_orders_suppliers")
Filtro_index_1
#Realizamos grafica de pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_2= freq_tbl(Micro_Retailer["38_average_margin_profits"])
Filtro_2= table_2[table_2["frequency"]>1]
Filtro_index_2=Filtro_2.set_index("38_average_margin_profits")
Filtro_index_2["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_3= freq_tbl(Micro_Retailer["59_willingness_share_sales_data_mse_better_prices"])
Filtro_3= table_3[table_3["frequency"]>1]
Filtro_index_3=Filtro_3.set_index("59_willingness_share_sales_data_mse_better_prices")
Filtro_index_3
Filtro_index_3["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_4= freq_tbl(Micro_Retailer["193_sales_planning_tools"])
Filtro_4= table_4[table_4["frequency"]>1]
Filtro_index_4=Filtro_4.set_index("193_sales_planning_tools")
Filtro_index_4
Filtro_index_4["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_5= freq_tbl(Micro_Retailer["58_willingness_share_sales_data_mse"])
Filtro_5= table_5[table_5["frequency"]>1]
Filtro_index_5=Filtro_5.set_index("58_willingness_share_sales_data_mse")
Filtro_index_5
Filtro_index_5["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_6= freq_tbl(Micro_Retailer["53_special_conditions_suppliers"])
Filtro_6= table_6[table_6["frequency"]>1]
Filtro_index_6=Filtro_6.set_index("53_special_conditions_suppliers")
Filtro_index_6
Filtro_index_6["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_7= freq_tbl(Micro_Retailer["58_willingness_share_sales_data_mse"])
Filtro_7= table_7[table_7["frequency"]>1]
Filtro_index_7=Filtro_7.set_index("58_willingness_share_sales_data_mse")
Filtro_index_7
Filtro_index_7["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_8= freq_tbl(Micro_Retailer["60_services"])
Filtro_8= table_8[table_8["frequency"]>1]
Filtro_index_8=Filtro_8.set_index("60_services")
Filtro_index_8
Filtro_index_8["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_9= freq_tbl(Micro_Retailer["43_willingness_share_sales_data_suppliers"])
Filtro_9= table_9[table_9["frequency"]>1]
Filtro_index_9=Filtro_9.set_index("43_willingness_share_sales_data_suppliers")
Filtro_index_9
Filtro_index_9["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_10= freq_tbl(Micro_Retailer["64_comission_services"])
Filtro_10= table_10[table_10["frequency"]>1]
Filtro_index_10=Filtro_10.set_index("64_comission_services")
Filtro_index_10
Filtro_index_10["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_11= freq_tbl(Micro_Retailer["47_willingness_reorder_suppliers_lower_prices"])
Filtro_11= table_11[table_11["frequency"]>1]
Filtro_index_11=Filtro_11.set_index("47_willingness_reorder_suppliers_lower_prices")
Filtro_index_11
Filtro_index_11["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_12= freq_tbl(Micro_Retailer["278_credit_interest"])
Filtro_12= table_12[table_12["frequency"]>1]
Filtro_index_12=Filtro_12.set_index("278_credit_interest")
Filtro_index_12
Filtro_index_12["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_13= freq_tbl(Micro_Retailer["46_willingness_reorder_suppliers_variety"])
Filtro_13= table_13[table_13["frequency"]>1]
Filtro_index_13=Filtro_13.set_index("46_willingness_reorder_suppliers_variety")
Filtro_index_13
Filtro_index_13["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_14= freq_tbl(Micro_Retailer["69_why_not_services"])
Filtro_14= table_14[table_14["frequency"]>1]
Filtro_index_14=Filtro_14.set_index("69_why_not_services")
Filtro_index_14
Filtro_index_14["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_15= freq_tbl(Micro_Retailer["44_willingness_inventory_management_suppliers"])
Filtro_15= table_15[table_15["frequency"]>1]
Filtro_index_15=Filtro_15.set_index("44_willingness_inventory_management_suppliers")
Filtro_index_15
Filtro_index_15["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_16= freq_tbl(Micro_Retailer["311_topups"])
Filtro_16= table_16[table_16["frequency"]>1]
Filtro_index_16=Filtro_16.set_index("311_topups")
Filtro_index_16
Filtro_index_16["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_17= freq_tbl(Micro_Retailer["314_reception_delivery_packages"])
Filtro_17= table_17[table_17["frequency"]>1]
Filtro_index_17=Filtro_17.set_index("314_reception_delivery_packages")
Filtro_index_17
Filtro_index_17["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_18= freq_tbl(Micro_Retailer["312_payment_of_utilities"])
Filtro_18= table_18[table_18["frequency"]>1]
Filtro_index_18=Filtro_18.set_index("312_payment_of_utilities")
Filtro_index_18
Filtro_index_18["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_19= freq_tbl(Micro_Retailer["313_home_deliveries"])
Filtro_19= table_19[table_19["frequency"]>1]
Filtro_index_19=Filtro_19.set_index("313_home_deliveries")
Filtro_index_19
Filtro_index_19["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table_20= freq_tbl(Micro_Retailer["43_willingness_share_sales_data_suppliers"])
Filtro_20= table_20[table_20["frequency"]>1]
Filtro_index_20=Filtro_20.set_index("43_willingness_share_sales_data_suppliers")
Filtro_index_20
Filtro_index_20["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
